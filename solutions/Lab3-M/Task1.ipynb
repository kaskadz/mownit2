# %%
using DataFrames
using Plots
using Statistics
using CSV

# %%
function naive_multiplication(A, B)
    C = zeros(Float64, size(A, 1), size(B, 2))
    for i = 1:size(A, 1)
        for j = 1:size(B, 2)
            for k = 1:size(A, 2)
                C[i, j] = C[i, j] + A[i, k] * B[k, j]
            end
        end
    end
    C
end
# Out:
# naive_multiplication (generic function with 1 method)

# %%
function better_multiplication(A, B)
    C = zeros(Float64, size(A, 1), size(B, 2))        
    for i = 1:size(B, 2)                           
        for j = 1:size(A, 2)                       
            for k = 1:size(A, 1)                   
                C[k, i] = C[k, i] + A[k, j] * B[j, i]
            end
        end
    end
    C
end
# Out:
# better_multiplication (generic function with 1 method)

# %%
function run_naive_multiplication(x1, y1, x2, y2)
    A = rand(Float64, x1 * y1 )
    A = reshape(A, y1, x1)

    B = rand(Float64, x2 * y2 )
    B = reshape(B, y2, x2)

    return @elapsed naive_multiplication(A, B)
end
# Out:
# run_naive_multiplication (generic function with 1 method)

# %%
function run_better_multiplication(x1, y1, x2, y2)
    A = rand(Float64, x1 * y1 )
    A = reshape(A, y1, x1)

    B = rand(Float64, x2 * y2 )
    B = reshape(B, y2, x2)

    return @elapsed better_multiplication(A, B)
end
# Out:
# run_better_multiplication (generic function with 1 method)

# %%
function run_lib_multiplication(x1, y1, x2, y2)
    A = rand(Float64, x1 * y1 )
    A = reshape(A, y1, x1)

    B = rand(Float64, x2 * y2 )
    B = reshape(B, y2, x2)

    return @elapsed A * B
end
# Out:
# run_lib_multiplication (generic function with 1 method)

# %%
sizes = [1, 50, 100, 500, 1000, 1100, 1200, 1300, 1400, 1500]

measurements = size(sizes)[:1]
repetitions = 10
data_count = measurements * repetitions

println("measurements:")
println(measurements)
println("repetitions:")
println(repetitions)
# Out:
# measurements:
# 10
# repetitions:
# 10

# %%
df = DataFrame(Size = Int64[], Type = String[], Time = Float64[])
show(df)
# Out:
# 0×3 DataFrame

# %%
for i = 1:measurements
    for j = 1:repetitions
        time = run_naive_multiplication(sizes[i], sizes[i], sizes[i], sizes[i])
        
        push!(df, (sizes[i], "naive", time))

        print((i - 1) * measurements + j)
        print("/")
        println(data_count)
    end
end
# Out:
# 1/100
# 2/100
# 3/100
# 4/100
# 5/100
# 6/100
# 7/100
# 8/100
# 9/100
# 10/100
# 11/100
# 12/100
# 13/100
# 14/100
# 15/100
# 16/100
# 17/100
# 18/100
# 19/100
# 20/100
# 21/100
# 22/100
# 23/100
# 24/100
# 25/100
# 26/100
# 27/100
# 28/100
# 29/100
# 30/100
# 31/100
# 32/100
# 33/100
# 34/100
# 35/100
# 36/100
# 37/100
# 38/100
# 39/100
# 40/100
# 41/100
# 42/100
# 43/100
# 44/100
# 45/100
# 46/100
# 47/100
# 48/100
# 49/100
# 50/100
# 51/100
# 52/100
# 53/100
# 54/100
# 55/100
# 56/100
# 57/100
# 58/100
# 59/100
# 60/100
# 61/100
# 62/100
# 63/100
# 64/100
# 65/100
# 66/100
# 67/100
# 68/100
# 69/100
# 70/100
# 71/100
# 72/100
# 73/100
# 74/100
# 75/100
# 76/100
# 77/100
# 78/100
# 79/100
# 80/100
# 81/100
# 82/100
# 83/100
# 84/100
# 85/100
# 86/100
# 87/100
# 88/100
# 89/100
# 90/100
# 91/100
# 92/100
# 93/100
# 94/100
# 95/100
# 96/100
# 97/100
# 98/100
# 99/100
# 100/100

# %%
for i = 1:measurements
    for j = 1:repetitions
        time = run_better_multiplication(sizes[i], sizes[i], sizes[i], sizes[i])
        
        push!(df, (sizes[i], "better", time))

        print((i - 1) * measurements + j)
        print("/")
        println(data_count)
    end
end
# Out:
# 1/100
# 2/100
# 3/100
# 4/100
# 5/100
# 6/100
# 7/100
# 8/100
# 9/100
# 10/100
# 11/100
# 12/100
# 13/100
# 14/100
# 15/100
# 16/100
# 17/100
# 18/100
# 19/100
# 20/100
# 21/100
# 22/100
# 23/100
# 24/100
# 25/100
# 26/100
# 27/100
# 28/100
# 29/100
# 30/100
# 31/100
# 32/100
# 33/100
# 34/100
# 35/100
# 36/100
# 37/100
# 38/100
# 39/100
# 40/100
# 41/100
# 42/100
# 43/100
# 44/100
# 45/100
# 46/100
# 47/100
# 48/100
# 49/100
# 50/100
# 51/100
# 52/100
# 53/100
# 54/100
# 55/100
# 56/100
# 57/100
# 58/100
# 59/100
# 60/100
# 61/100
# 62/100
# 63/100
# 64/100
# 65/100
# 66/100
# 67/100
# 68/100
# 69/100
# 70/100
# 71/100
# 72/100
# 73/100
# 74/100
# 75/100
# 76/100
# 77/100
# 78/100
# 79/100
# 80/100
# 81/100
# 82/100
# 83/100
# 84/100
# 85/100
# 86/100
# 87/100
# 88/100
# 89/100
# 90/100
# 91/100
# 92/100
# 93/100
# 94/100
# 95/100
# 96/100
# 97/100
# 98/100
# 99/100
# 100/100

# %%
for i = 1:measurements
    for j = 1:repetitions
        time = run_lib_multiplication(sizes[i], sizes[i], sizes[i], sizes[i])
        
        push!(df, (sizes[i], "lib", time))

        print((i - 1) * measurements + j)
        print("/")
        println(data_count)
    end
end
# Out:
# 1/100
# 2/100
# 3/100
# 4/100
# 5/100
# 6/100
# 7/100
# 8/100
# 9/100
# 10/100
# 11/100
# 12/100
# 13/100
# 14/100
# 15/100
# 16/100
# 17/100
# 18/100
# 19/100
# 20/100
# 21/100
# 22/100
# 23/100
# 24/100
# 25/100
# 26/100
# 27/100
# 28/100
# 29/100
# 30/100
# 31/100
# 32/100
# 33/100
# 34/100
# 35/100
# 36/100
# 37/100
# 38/100
# 39/100
# 40/100
# 41/100
# 42/100
# 43/100
# 44/100
# 45/100
# 46/100
# 47/100
# 48/100
# 49/100
# 50/100
# 51/100
# 52/100
# 53/100
# 54/100
# 55/100
# 56/100
# 57/100
# 58/100
# 59/100
# 60/100
# 61/100
# 62/100
# 63/100
# 64/100
# 65/100
# 66/100
# 67/100
# 68/100
# 69/100
# 70/100
# 71/100
# 72/100
# 73/100
# 74/100
# 75/100
# 76/100
# 77/100
# 78/100
# 79/100
# 80/100
# 81/100
# 82/100
# 83/100
# 84/100
# 85/100
# 86/100
# 87/100
# 88/100
# 89/100
# 90/100
# 91/100
# 92/100
# 93/100
# 94/100
# 95/100
# 96/100
# 97/100
# 98/100
# 99/100
# 100/100

# %%
df
# Out:
# 300×3 DataFrame
# │ Row │ Size  │ Type   │ Time     │
# │     │ Int64 │ String │ Float64  │
# ├─────┼───────┼────────┼──────────┤
# │ 1   │ 1     │ naive  │ 1.0e-6   │
# │ 2   │ 1     │ naive  │ 2.0e-7   │
# │ 3   │ 1     │ naive  │ 2.0e-7   │
# │ 4   │ 1     │ naive  │ 0.0      │
# │ 5   │ 1     │ naive  │ 2.0e-7   │
# │ 6   │ 1     │ naive  │ 0.0      │
# │ 7   │ 1     │ naive  │ 0.0      │
# │ 8   │ 1     │ naive  │ 0.0      │
# │ 9   │ 1     │ naive  │ 1.0e-7   │
# │ 10  │ 1     │ naive  │ 1.0e-7   │
# ⋮
# │ 290 │ 1400  │ lib    │ 0.184834 │
# │ 291 │ 1500  │ lib    │ 0.196988 │
# │ 292 │ 1500  │ lib    │ 0.19486  │
# │ 293 │ 1500  │ lib    │ 0.199524 │
# │ 294 │ 1500  │ lib    │ 0.112396 │
# │ 295 │ 1500  │ lib    │ 0.19897  │
# │ 296 │ 1500  │ lib    │ 0.195174 │
# │ 297 │ 1500  │ lib    │ 0.197462 │
# │ 298 │ 1500  │ lib    │ 0.190257 │
# │ 299 │ 1500  │ lib    │ 0.197102 │
# │ 300 │ 1500  │ lib    │ 0.192757 │

# %%
CSV.write("julia.csv", df)
# Out:
# "julia.csv"

# %%
df_agg = by(df, [:Size, :Type]) do subGroup
    DataFrame(AvgTime = mean(subGroup.Time), StDev = std(subGroup.Time))
end
# Out:
# 30×4 DataFrame
# │ Row │ Size  │ Type   │ AvgTime     │ StDev       │
# │     │ Int64 │ String │ Float64     │ Float64     │
# ├─────┼───────┼────────┼─────────────┼─────────────┤
# │ 1   │ 1     │ naive  │ 1.8e-7      │ 3.01109e-7  │
# │ 2   │ 50    │ naive  │ 0.000354948 │ 6.04135e-5  │
# │ 3   │ 100   │ naive  │ 0.00304811  │ 0.000308221 │
# │ 4   │ 500   │ naive  │ 0.394643    │ 0.00454199  │
# │ 5   │ 1000  │ naive  │ 3.17161     │ 0.0352266   │
# │ 6   │ 1100  │ naive  │ 4.22461     │ 0.0406963   │
# │ 7   │ 1200  │ naive  │ 5.50978     │ 0.0382339   │
# │ 8   │ 1300  │ naive  │ 6.96317     │ 0.0541924   │
# │ 9   │ 1400  │ naive  │ 8.8147      │ 0.164921    │
# │ 10  │ 1500  │ naive  │ 11.1342     │ 0.354984    │
# ⋮
# │ 20  │ 1500  │ better │ 5.37765     │ 0.0950349   │
# │ 21  │ 1     │ lib    │ 5.52897e-5  │ 0.000173506 │
# │ 22  │ 50    │ lib    │ 2.04698e-5  │ 7.08776e-6  │
# │ 23  │ 100   │ lib    │ 0.000117359 │ 0.000186357 │
# ...

# %%
sort(df_agg, [:Size, :AvgTime])
# Out:
# 30×4 DataFrame
# │ Row │ Size  │ Type   │ AvgTime     │ StDev       │
# │     │ Int64 │ String │ Float64     │ Float64     │
# ├─────┼───────┼────────┼─────────────┼─────────────┤
# │ 1   │ 1     │ naive  │ 1.8e-7      │ 3.01109e-7  │
# │ 2   │ 1     │ better │ 2.1e-7      │ 1.79196e-7  │
# │ 3   │ 1     │ lib    │ 5.52897e-5  │ 0.000173506 │
# │ 4   │ 50    │ lib    │ 2.04698e-5  │ 7.08776e-6  │
# │ 5   │ 50    │ better │ 0.000190099 │ 3.6201e-5   │
# │ 6   │ 50    │ naive  │ 0.000354948 │ 6.04135e-5  │
# │ 7   │ 100   │ lib    │ 0.000117359 │ 0.000186357 │
# │ 8   │ 100   │ better │ 0.00152556  │ 7.02012e-5  │
# │ 9   │ 100   │ naive  │ 0.00304811  │ 0.000308221 │
# │ 10  │ 500   │ lib    │ 0.0052335   │ 0.0101776   │
# ⋮
# │ 20  │ 1200  │ better │ 2.78233     │ 0.0896698   │
# │ 21  │ 1200  │ naive  │ 5.50978     │ 0.0382339   │
# │ 22  │ 1300  │ lib    │ 0.118961    │ 0.0338567   │
# │ 23  │ 1300  │ better │ 3.54239     │ 0.0759262   │
# ...

# %%
df_agg[:Type] .== "naive"
df_naive = df_agg[df_agg[:Type] .== "naive", :]
# Out:
# 10×4 DataFrame
# │ Row │ Size  │ Type   │ AvgTime     │ StDev       │
# │     │ Int64 │ String │ Float64     │ Float64     │
# ├─────┼───────┼────────┼─────────────┼─────────────┤
# │ 1   │ 1     │ naive  │ 1.8e-7      │ 3.01109e-7  │
# │ 2   │ 50    │ naive  │ 0.000354948 │ 6.04135e-5  │
# │ 3   │ 100   │ naive  │ 0.00304811  │ 0.000308221 │
# │ 4   │ 500   │ naive  │ 0.394643    │ 0.00454199  │
# │ 5   │ 1000  │ naive  │ 3.17161     │ 0.0352266   │
# │ 6   │ 1100  │ naive  │ 4.22461     │ 0.0406963   │
# │ 7   │ 1200  │ naive  │ 5.50978     │ 0.0382339   │
# │ 8   │ 1300  │ naive  │ 6.96317     │ 0.0541924   │
# │ 9   │ 1400  │ naive  │ 8.8147      │ 0.164921    │
# │ 10  │ 1500  │ naive  │ 11.1342     │ 0.354984    │

# %%
df_better = df_agg[df_agg[:Type] .== "better", :]
# Out:
# 10×4 DataFrame
# │ Row │ Size  │ Type   │ AvgTime     │ StDev      │
# │     │ Int64 │ String │ Float64     │ Float64    │
# ├─────┼───────┼────────┼─────────────┼────────────┤
# │ 1   │ 1     │ better │ 2.1e-7      │ 1.79196e-7 │
# │ 2   │ 50    │ better │ 0.000190099 │ 3.6201e-5  │
# │ 3   │ 100   │ better │ 0.00152556  │ 7.02012e-5 │
# │ 4   │ 500   │ better │ 0.199425    │ 0.00522593 │
# │ 5   │ 1000  │ better │ 1.56338     │ 0.0153139  │
# │ 6   │ 1100  │ better │ 2.08247     │ 0.0128393  │
# │ 7   │ 1200  │ better │ 2.78233     │ 0.0896698  │
# │ 8   │ 1300  │ better │ 3.54239     │ 0.0759262  │
# │ 9   │ 1400  │ better │ 4.50879     │ 0.108504   │
# │ 10  │ 1500  │ better │ 5.37765     │ 0.0950349  │

# %%
df_lib = df_agg[df_agg[:Type] .== "lib", :]
# Out:
# 10×4 DataFrame
# │ Row │ Size  │ Type   │ AvgTime     │ StDev       │
# │     │ Int64 │ String │ Float64     │ Float64     │
# ├─────┼───────┼────────┼─────────────┼─────────────┤
# │ 1   │ 1     │ lib    │ 5.52897e-5  │ 0.000173506 │
# │ 2   │ 50    │ lib    │ 2.04698e-5  │ 7.08776e-6  │
# │ 3   │ 100   │ lib    │ 0.000117359 │ 0.000186357 │
# │ 4   │ 500   │ lib    │ 0.0052335   │ 0.0101776   │
# │ 5   │ 1000  │ lib    │ 0.0666596   │ 0.0369342   │
# │ 6   │ 1100  │ lib    │ 0.0556828   │ 0.041434    │
# │ 7   │ 1200  │ lib    │ 0.0981019   │ 0.00207952  │
# │ 8   │ 1300  │ lib    │ 0.118961    │ 0.0338567   │
# │ 9   │ 1400  │ lib    │ 0.159936    │ 0.0437606   │
# │ 10  │ 1500  │ lib    │ 0.187549    │ 0.026555    │

# %%
plot(df_lib[:Size], [df_naive[:AvgTime], df_better[:AvgTime], df_lib[:AvgTime]], label = ["naive", "better", "lib"], size = (1000, 600))
scatter!(df_lib[:Size], df_naive[:AvgTime], yerr = df_naive[:StDev], label = "naive")
scatter!(df_lib[:Size], df_better[:AvgTime], yerr = df_better[:StDev], label = "better")
scatter!(df_lib[:Size], df_lib[:AvgTime], yerr = df_lib[:StDev], label = "lib")
